# %%
# %matplotlib inline

# %%
import torchio as tio
import torch

# rsync -azvP supercloud:/home/gridsan/nchutisilp/datasets/nnUNet_Datasets/nnUNet_results/Dataset302_Calcium_OCTv2/nnUNetTrainer__nnUNetPlans__2d/fold_0_test/*.nii.gz /home/naravich/projects/ModelsGenesis/notebooks/predictions/3d_32x512x512_b2/2d/fold_0/

subject=  tio.Subject(
    image = tio.ScalarImage('/storage_bizon/naravich/nnUNet_Datasets/nnUNet_raw/Dataset302_Calcium_OCTv2/imagesTs/101-045_0000.nii.gz'),
    ground_truth = tio.ScalarImage('/storage_bizon/naravich/nnUNet_Datasets/nnUNet_raw/Dataset302_Calcium_OCTv2/labelsTs/101-045.nii.gz'),
    pred_3d_32x512x512=tio.ScalarImage('/home/naravich/projects/ModelsGenesis/notebooks/predictions/3d_32x512x512_b2/fold_0/101-045.nii.gz'),
    pred_3d_32x160x128=tio.ScalarImage('/home/naravich/projects/ModelsGenesis/notebooks/predictions/3d_32x160x128_b10/fold_0/101-045.nii.gz'),
    pred_2d_512x512=tio.ScalarImage('/home/naravich/projects/ModelsGenesis/notebooks/predictions/2d/fold_0/101-045.nii.gz')
)

subject.plot(figsize=(15, 15))

# %%
subject=  tio.Subject(
    image = tio.ScalarImage('/storage_bizon/naravich/nnUNet_Datasets/nnUNet_raw/Dataset302_Calcium_OCTv2/imagesTs/706-005_0000.nii.gz'),
    ground_truth = tio.ScalarImage('/storage_bizon/naravich/nnUNet_Datasets/nnUNet_raw/Dataset302_Calcium_OCTv2/labelsTs/706-005.nii.gz'),
    pred_3d_32x512x512=tio.ScalarImage('/home/naravich/projects/ModelsGenesis/notebooks/predictions/3d_32x512x512_b2/fold_0/706-005.nii.gz'),
    pred_3d_32x160x128=tio.ScalarImage('/home/naravich/projects/ModelsGenesis/notebooks/predictions/3d_32x160x128_b10/fold_0/706-005.nii.gz'),
    pred_2d_512x512=tio.ScalarImage('/home/naravich/projects/ModelsGenesis/notebooks/predictions/2d/fold_0/706-005.nii.gz')
)

subject.plot(figsize=(15, 15))
